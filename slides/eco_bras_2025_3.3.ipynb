# %% [markdown]
# ## <center>Economia Brasileira I - FEA-USP</center>
#
# ### <center>Aula 3 - Retomada do Crescimento e “Milagre Econômico” (parte 3)</center>
#
# #### <center>Renato Perim Colistete</center>
#
#
# #### <center>2025</center>

# %% [markdown]
# ## Objetivos
#
# Apresentaremos hoje um panorama das principais tendências econômicas do período do “milagre econômico”, começando com a questão central do endividamento externo (ainda voltaremos ao tema posteriormente).
#
# Veremos os dados básicos das contas externas, organizadas nas categorias de comércio/serviços, investimento direto e empréstimos.
#
# Resumiremos depois os indicadores de crescimento do produto, dos salários e da produtividade. E faremos a seguinte pergunta: qual foi o resultado do período em termos de distribuição da renda (na indústria)?

# %% [markdown]
# ## Dívida externa
#
# O endividamento externo brasileiro manteve-se estável até 1967/68, a partir de quando começou a acelerar-se rapidamente: US\\$ 3,8 bilhões em 1968 para US$ 12,6 bilhões em 1973. Esse crescimento coincide com a expansão do *Euromercado* (ver um resumo [aqui](https://en.wikipedia.org/wiki/Eurodollar)).

# %% [markdown]
# O nível de reservas durante esse período também manteve-se baixo na maior parte da década de 1960, causando grande incerteza sobre a capacidade de pagamento do país.

# %% [markdown]
# Mas em seguida, acompanhando o endividamento externo, as reservas também cresceram – em 1968 = US\\$ 0,4 bilhão e em 1973 = US$ 6,4 bilhões (conf. figura). Ver também o desempenho global do balanço de pagamentos.

# %%
import pandas as pd
import numpy as np

import holoviews as hv
from holoviews import dim, opts
import hvplot.pandas
hv.extension('bokeh', 'matplotlib')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='3d02f3fe-ded4-463e-9952-4a2ea0c5fc46'>
#   <div id="c5bb43f2-d472-47eb-8e78-114ae3ae56c5" data-root-id="3d02f3fe-ded4-463e-9952-4a2ea0c5fc46" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"5d6ace26-9d4e-4efb-a012-c9bf3cafd480":{"version":"3.4.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"3d02f3fe-ded4-463e-9952-4a2ea0c5fc46"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"9c74068c-1716-40a3-988f-304e4a5eb516","attributes":{"plot_id":"3d02f3fe-ded4-463e-9952-4a2ea0c5fc46","comm_id":"7fda3f5d8f9448328a7799327b15b342","client_comm_id":"cd4f3e275618481b80a79299039a9b23"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"5d6ace26-9d4e-4efb-a012-c9bf3cafd480","roots":{"3d02f3fe-ded4-463e-9952-4a2ea0c5fc46":"c5bb43f2-d472-47eb-8e78-114ae3ae56c5"},"root_ids":["3d02f3fe-ded4-463e-9952-4a2ea0c5fc46"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
div = pd.read_excel('br_divida_ext_milagre.xlsx')

dívida = div.hvplot.bar('Ano', ['Dívida externa bruta', 'Reservas internacionais'],
                        height=400,
                        width=620,
                        rot=0,
                        stacked=True,
                        padding=0.02,
                        legend='bottom',
                        cmap='tab20',
                        yformatter='%f',
                        ylim=(0, 19000),
                        yticks=10,
                        xlabel='',
                        ylabel='Milhões de dólares',
                        label='Dívida externa e reservas, Brasil, 1960-1973 (em milhões de US$)'
                       ).opts(fontsize={'title': 10, 'labels': 8, 'xticks': 8, 'yticks': 8, 'legend': 9})

# %%
dívida
# Out:
# :Bars   [Ano,Variable]   (value)

# %% [markdown]
# ## Definições e dados
#
# Antes dos dados, lembrar das definições básicas:
#
#  1 - Balança comercial = X - M
#
#  2 - Balança de serviços = transporte (fretes, seguros), turismo, juros, lucros e dividendos
#
#  3 - **Saldo das transações correntes = Balança comercial + Balança de serviços**
#
#  4 - Conta de capitais = Investimento Direto Estrangeiro (IDE), empréstimos e financiamentos, amortizações
#
#  5 - **Saldo do balanço de pagamentos = Saldo das transações correntes + Conta de capitais**
#
#  8 - Variação das reservas

# %%
bp = pd.read_excel('br_bp_milagre.xlsx')

BP = bp.hvplot.bar('Ano', ['Balança comercial', 'Transações correntes', 'Capitais', 'Saldo do BP'],
                   height=400,
                   width=620,
                   rot=0,
                   padding=0.02,
                   legend='bottom',
                   cmap='Set2',
                   ylim=(-2000, 6000),
                   yticks=6,
                   stacked=True,
                   xlabel='Ano',
                   xlim=(1963, 1974),
                   xticks=10,
                   ylabel='Milhões de dólares',
                   grid=False,
                   label='Balanço de pagamentos, Brasil, 1964-1973 (em milhões de US$)'
                   ).opts(fontsize={'title': 10, 'labels': 8, 'xticks': 8, 'yticks': 8, 'legend': 9}, xticks=list(range(1964, 1974)))

# %%
BP
# Out:
# :Bars   [Ano,Variable]   (value)

# %% [markdown]
# ## Interpretação
#
# Quais foram os fatores mais importantes que explicam o endividamento externo no período 1969-1973?

# %% [markdown]
# Davidoff Cruz (1984) reclassificou as contas do balanço de pagamentos em:

# %% [markdown]
# - contas de comércio de mercadorias (X-M) e serviços produtivos (apenas transportes, seguros e *royalties*);

# %% [markdown]
# - contas de capital de risco = investimentos diretos - remessas de lucros e dividendos;

# %% [markdown]
# - contas de capital de empréstimo = (financiamento de importações + empréstimos em moeda) - amortizações - juros líquidos. As reservas internacionais são uma conta de resíduo.

# %% [markdown]
# ## Comércio e serviços
#
# Com essa classificação, vê-se a seguir que o saldo da balança comercial foi, no conjunto, equilibrado entre 1969-1973 (US\\$ -0,03 bilhão), mas o balanço de "serviços produtivos" ou "não financeiros" foi negativo (US$ -2,06 bilhões).

# %% [markdown]
# Portanto, a conta de serviços produtivos teve um papel expressivo na captação de recursos externos no período. Por outro lado, a entrada de investimento direto (US\\$ 1,82 bilhão) compensou largamente as remessas de lucros e dividendos (US$ 0,68 bilhão).

# %% [markdown]
# Ou seja, de acordo com Davidoff Cruz (1984), do ponto de vista dos recursos que ele chama de “produtivos” ou "não financeiros", a pressão maior ocorreu na conta de serviços e em parte foi compensada pelos investimentos diretos do exterior entre 1969-73.

# %% [markdown]
# Notem que as importações cresceram bastante no período, com déficits comerciais em 1971-72. Ainda assim, na maior parte dos anos esse aumento foi compensado pela expansão das exportações, inclusive as de manufaturados. Ver figura.

# %%
import pandas as pd
import holoviews as hv
import hvplot.pandas

hv.extension('bokeh')

c = pd.read_excel('br_bcom_milagre.xlsx')
c['Ano'] = c['Ano'].astype(str) 

df_long = c.melt(
    id_vars='Ano',
    value_vars=['Exportações', 'Importações', 'Saldo da Balança Comercial'],
    var_name='Categoria',
    value_name='Valor'
)

Comércio = df_long.hvplot.bar(
    x='Ano',
    y='Valor',
    by='Categoria',
    width=620,
    height=400,
    rot=0,
    padding=0.02,
    cmap='tab10',
    ylim=(-500, 7000),
    legend='bottom',
    xlabel='Ano',
    ylabel='Milhões de dólares',
    title='Exportações e importações, Brasil, 1964-1973 (em milhões de US$)'
).opts(
    fontsize={'title': 10.5, 'labels': 8, 'xticks': 8, 'yticks': 8, 'legend': 9},
    multi_level=False
)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='242a00e5-fe4d-4e46-a9c9-975e52f432c9'>
#   <div id="b021c8d3-b1d5-4e8e-9da9-68d40458abab" data-root-id="242a00e5-fe4d-4e46-a9c9-975e52f432c9" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"9c3b51b0-e63d-4b0c-9a7e-e7e48a247b24":{"version":"3.4.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"242a00e5-fe4d-4e46-a9c9-975e52f432c9"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"b923aa04-3828-4551-a133-4a854b403d91","attributes":{"plot_id":"242a00e5-fe4d-4e46-a9c9-975e52f432c9","comm_id":"de27e0e2fa7447afb813183e01df021c","client_comm_id":"72a6bc4b6af842f5a92cc9cf6efcaec0"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"9c3b51b0-e63d-4b0c-9a7e-e7e48a247b24","roots":{"242a00e5-fe4d-4e46-a9c9-975e52f432c9":"b021c8d3-b1d5-4e8e-9da9-68d40458abab"},"root_ids":["242a00e5-fe4d-4e46-a9c9-975e52f432c9"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
Comércio
# Out:
# :Bars   [Ano,Categoria]   (Valor)

# %%
import pandas as pd
import holoviews as hv
import hvplot.pandas

hv.extension('bokeh')

s = pd.read_excel('br_produtive_bp_milagre.xlsx')

saldos_1 = s.hvplot.bar(
    x='Contas',
    y='Valores em US$ bilhão',
    height=450,
    width=620,
    cmap='tab20c',
    rot=40,
    padding=0.02,
    ylim=(-3, 3),
    yticks=10,
    xlabel='',
    ylabel='',
    legend='bottom',
    color='darkgreen',
    label='Saldos de contas não financeiras do BP, Brasil, 1969-1973 (US$)'
).opts(
    fontsize={'title': 10.0, 'labels': 8, 'xticks': 8, 'yticks': 8, 'legend': 9},
    multi_level=False
)

linha_zero = hv.HLine(0).opts(color='black', line_width=1)

saldos = saldos_1 * linha_zero
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='f76b0eb0-83cf-441f-84c5-3fc481d56121'>
#   <div id="d6c1dea7-1d1b-4050-bd62-acb58287fc57" data-root-id="f76b0eb0-83cf-441f-84c5-3fc481d56121" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"f91e4c48-09b6-4ac5-97be-0cdf64b42707":{"version":"3.4.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"f76b0eb0-83cf-441f-84c5-3fc481d56121"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"dc750116-4466-4eda-a45e-a613b47214cf","attributes":{"plot_id":"f76b0eb0-83cf-441f-84c5-3fc481d56121","comm_id":"6ef8b4c4edda44599d1d39ae665e883f","client_comm_id":"3ae911da1a38418b837e4dfb651266fb"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"f91e4c48-09b6-4ac5-97be-0cdf64b42707","roots":{"f76b0eb0-83cf-441f-84c5-3fc481d56121":"d6c1dea7-1d1b-4050-bd62-acb58287fc57"},"root_ids":["f76b0eb0-83cf-441f-84c5-3fc481d56121"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
saldos
# Out:
# :Overlay
#    .Bars.Saldos_de_contas_não_financeiras_do_BP_comma_Brasil_comma_1969_hyphen_minus_1973_left_parenthesis_US_right_parenthesis :Bars   [Contas]   (Valores em US$ bilhão)
#    .HLine.I                                                                                                                     :HLine   [x,y]

# %% [markdown]
# ## Empréstimos
#
# A situação muda quando olhamos as contas ditas “financeiras”, ou seja, as contas relativas a financiamentos e capital de empréstimo. Na figura a seguir são apresentados os seus principais itens.

# %% [markdown]
# Os financiamentos às importações (US\\$ 4,29 bilhões) e os empréstimos em moeda (US$ 10,07 bilhões) atingem níveis
# elevados, dadas as facilidades de captação externa na época, francamente incentivada pelo governo (p.ex., Resolução 63).

# %% [markdown]
# As amortizações de empréstimos chegaram a US\\$ 7,61 bilhões, somadas aos pagamentos de juros, de US$ 1,78 bilhões. Mesmo assim, observar o aumento nas reservas em moeda estrangeira (US\\$ 6,16 bilhões).

# %%
import pandas as pd
import holoviews as hv
import hvplot.pandas

hv.extension('bokeh')

p = pd.read_excel('br_noprodutive_bp_milagre.xlsx')

saldos_2 = p.hvplot.bar(
    x='Contas',
    y='Valores em US$ bilhão',
    height=450,
    width=620,
    color='orange',
    rot=40,
    padding=0.02,
    ylim=(-10, 12),
    yticks=10,
    xlabel='',
    ylabel='',
    legend='bottom',
    label='Saldos de contas financeiras do BP, Brasil, 1969-1973 (US$)'
).opts(
    fontsize={'title': 10.0, 'labels': 8, 'xticks': 8, 'yticks': 8, 'legend': 9},
    multi_level=False
)

linha_zero = hv.HLine(0).opts(color='black', line_width=1)

saldos_2 = saldos_2 * linha_zero
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='6e020183-2ac7-42b6-bd44-9e5184ec7264'>
#   <div id="c8083663-1624-410a-abfb-680111ab9449" data-root-id="6e020183-2ac7-42b6-bd44-9e5184ec7264" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"c0865af5-3c24-46bb-9d67-7a37372eda29":{"version":"3.4.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"6e020183-2ac7-42b6-bd44-9e5184ec7264"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"409247d6-7865-4109-8ec3-617f2626ea3c","attributes":{"plot_id":"6e020183-2ac7-42b6-bd44-9e5184ec7264","comm_id":"f2de06fd19b04cbdbd9d0703a9f40315","client_comm_id":"8f9118894de04edfaf52ff28467dd60f"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"c0865af5-3c24-46bb-9d67-7a37372eda29","roots":{"6e020183-2ac7-42b6-bd44-9e5184ec7264":"c8083663-1624-410a-abfb-680111ab9449"},"root_ids":["6e020183-2ac7-42b6-bd44-9e5184ec7264"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
saldos_2
# Out:
# :Overlay
#    .Bars.Saldos_de_contas_financeiras_do_BP_comma_Brasil_comma_1969_hyphen_minus_1973_left_parenthesis_US_right_parenthesis :Bars   [Contas]   (Valores em US$ bilhão)
#    .HLine.I                                                                                                                 :HLine   [x,y]

# %% [markdown]
# ## Natureza da dívida
#
# Davidoff Cruz (1984) argumenta que “*a contrapartida do significativo impulso sofrido pela dívida externa deve ser
# buscada na esfera das relações financeiras da economia brasileira com o resto do mundo*” – e não, segundo o autor, na necessidade de poupança externa (= déficit nas transações correntes) ou no estrangulamento externo.

# %% [markdown]
# Observe que Davidoff Cruz considera como “financeiros” (no sentido de “não produtivos”) os recursos captados na forma de financiamento às importações, além dos empréstimos em moeda.

# %% [markdown]
# Em que medida essa classificação é adequada para retratar os fluxos de capital da época?

# %% [markdown]
# ## Crescimento
#
# Vejamos outros agregados macroeconômicos do período 1968-1973. O crescimento econômico foi excepcional: 11,2% a.a. do PIB e 13,3% a.a. do produto industrial entre 1968-1973 (lembrar, porém, da possível revisão do PIB recentemente).

# %% [markdown]
# Ainda assim, como vimos em aula passada: o grande crescimento populacional desde meados da década de 1940 relativiza o desempenho econômico do período quando visto pelo ângulo do PIB *per capita*.

# %% [markdown]
# As figuras a seguir mostram o crescimento de a) PIB e PIB *per capita* e b) PIB e produto industrial.

# %%
pibreal = pd.read_excel('br_pib_1901_75.xlsx')

PIB = pibreal.hvplot.line('Ano', ['PIB', 'PIB per capita'],
                          height=400,
                          width=620,
                          rot=0,
                          padding=0.09,
                          group_label='Produto',
                          legend='bottom',
                          xlabel='',
                          ylabel='Índice, 1901=100',
                          xlim=(1945, 1975),
                          xticks=5,
                          ylim=(0, 6000),
                          yticks=5,
                          grid=False,
                          title='PIB e PIB per capita, Brasil, 1945-1975 (em R$ de 1999, 1901=100)'
                         ).opts(fontsize={'title': 10, 'labels': 9, 'xticks': 9,'yticks': 9, 'legend': 9})

# %%
PIB
# Out:
# :NdOverlay   [Produto]
#    :Curve   [Ano]   (value)

# %% [markdown]
# ## População
#
# As características demográficas da população se alteraram substancialmente, em especial nos anos 1940 em diante, com reflexos diretos sobre a taxa de crescimento *per capita*, como visto no gráfico anterior.

# %%
import pandas as pd
import holoviews as hv
import hvplot.pandas

d = pd.read_excel('br_pop_1881_1975.xlsx')
d['Ano'] = d['Ano'].astype(str)

df_long = d.melt(id_vars=['Ano'], 
                 value_vars=['Natalidade', 'Mortalidade'], 
                 var_name='Taxa', 
                 value_name='Valor')

pop = df_long.hvplot.bar(
    x='Ano',
    y='Valor',
    by='Taxa',
    width=650,
    height=400,
    rot=45, 
    padding=0.02,
    legend='bottom',
    color=['#1f77b4', '#ff7f0e'], 
    title='Taxas brutas de natalidade e mortalidade, Brasil, 1881-1975',
    fontsize=12,
    yticks=10,
    ylim=(0, 50),
    yformatter='%.1f',
    xlabel='',
    ylabel='%'
).opts(multi_level=False)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='e7b44a82-5269-484b-8025-525fe32b8fae'>
#   <div id="b959d25b-ae68-487d-9c6b-8dc2c3c6ae50" data-root-id="e7b44a82-5269-484b-8025-525fe32b8fae" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"24d282a5-d310-4795-bef3-192677b42779":{"version":"3.4.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"e7b44a82-5269-484b-8025-525fe32b8fae"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"e581f8dc-dc36-43cc-a7ea-3e81eb29f2b1","attributes":{"plot_id":"e7b44a82-5269-484b-8025-525fe32b8fae","comm_id":"33586227dddf4f5890c40b5454846e90","client_comm_id":"aded84a200df4b719ef6d34e99f4f5d2"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"24d282a5-d310-4795-bef3-192677b42779","roots":{"e7b44a82-5269-484b-8025-525fe32b8fae":"b959d25b-ae68-487d-9c6b-8dc2c3c6ae50"},"root_ids":["e7b44a82-5269-484b-8025-525fe32b8fae"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
pop
# Out:
# :Bars   [Ano,Taxa]   (Valor)

# %%
import pandas as pd
import holoviews as hv
import hvplot.pandas

hv.extension('bokeh')

pr = pd.read_excel('br_ind_milagre.xlsx')
pr['Ano'] = pr['Ano'].astype(str)  

df_long = pr.melt(
    id_vars='Ano',
    value_vars=['PIB', 'Produto industrial'],
    var_name='Categoria',
    value_name='Valor'
)

produto = df_long.hvplot.bar(
    x='Ano',
    y='Valor',
    by='Categoria',
    height=400,
    width=620,
    rot=0,
    stacked=False,
    padding=0.02,
    legend='bottom',
    cmap='RdPu',
    yformatter='%.1f',
    ylabel='%',
    ylim=(0, 20),
    title='PIB e produto industrial, Brasil, 1966-1973 (taxa anual de crescimento, %)'
).opts(
    fontsize={'title': 9.6},
    multi_level=False
)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='cf9bfb6d-0764-457f-890b-b3bd7e015fbe'>
#   <div id="d552c201-890e-4058-ab8a-b13e03288def" data-root-id="cf9bfb6d-0764-457f-890b-b3bd7e015fbe" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"cf24d31d-6895-48f2-8566-0e376c57d63b":{"version":"3.4.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"cf9bfb6d-0764-457f-890b-b3bd7e015fbe"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"74bf8157-3971-4504-bc19-bacb932295b4","attributes":{"plot_id":"cf9bfb6d-0764-457f-890b-b3bd7e015fbe","comm_id":"41f4ae4f0a954a1f8969c47c99d56187","client_comm_id":"f36affef4256442097b6f57c6b188076"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"cf24d31d-6895-48f2-8566-0e376c57d63b","roots":{"cf9bfb6d-0764-457f-890b-b3bd7e015fbe":"d552c201-890e-4058-ab8a-b13e03288def"},"root_ids":["cf9bfb6d-0764-457f-890b-b3bd7e015fbe"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
produto
# Out:
# :Bars   [Ano,Categoria]   (Valor)

# %% [markdown]
# ## Salários
#
# Quanto aos salários, vimos que, no período anterior, o PAEG interveio diretamente no mercado de trabalho via fixação de salários e repressão sindical, constituindo um regime de compressão salarial.

# %% [markdown]
# Os salários médios do pessoal ocupado na indústria de transformação tiveram crescimento negativo em 1965, 1966 e 1967.

# %% [markdown]
# Também como vimos antes, houve grande aumento dos salários reais em 1963 (apesar da inflação crescente), uma evidência de maior conflito distributivo naquela conjuntura crítica.

# %% [markdown]
# Lembrar dos diferentes deflatores e das definições de salário-consumo e salário-produto.

# %%
w = pd.read_excel('br_sal_paeg.xlsx')

salários = w.hvplot.line('Ano', ['Salário-Consumo IPC-MTb', 'Salário-Consumo IPC-SP', 'Salário-Produto IPA-DI'],
                         height=400,
                         width=650,
                         rot=45,
                         padding=0.02,
                         group_label='Salário real por deflator',
                         legend='bottom',
                         cmap='tab10',
                         yformatter='%.1f',
                         xlabel='',
                         ylabel='taxa de crescimento anual, %',
                         xticks=20,
                         yticks=12,
                         ylim=(-15,25),
                         xlim=(1955, 1970),
                         title='Salários médios reais da indústria manufatureira, Brasil, 1955-1970 (%)'
                        ).opts(fontsize={'title': 10.5})

# %%
salários
# Out:
# :NdOverlay   [Salário real por deflator]
#    :Curve   [Ano]   (value)

# %% [markdown]
# ## Salário e produtividade
#
# Além do salário real, vimos que tão ou mais importante é avaliar o comportamento do salário na indústria brasileira *em relação* à produtividade do trabalho.

# %% [markdown]
# Conceito: **custo unitário do trabalho** (*unit labor cost* ou **ulc**), conf. definições e a figura a seguir.

# %% [markdown]
# Uma vez que
#
# ${w_n} = $ salário nominal,
#
# ${P} =$ Índice de Preço ao Produtor,
#
# ${L} =$ número de trabalhadores,
#
# ${O} =$ valor adicionado na produção.
#
# Temos, então,
#
# salário-produto $= w_r = \frac{w_n}{P}$,
#
# produtividade do trabalho $= lp = \frac{O}{L}$

# %% [markdown]
# ## Custo unitário do trabalho
#
# A partir das definições anteriores, obtemos o custo unitário do trabalho $= ulc = \frac{w_r}{lp}$

# %% [markdown]
# Ver a figura com os dados para indústria de transformação no Brasil entre 1950 e 1973.

# %% [markdown]
# Qual a tendência no período do PAEG em relação a salários, produtividade e custo unitário do trabalho?

# %%
wr = pd.read_excel('br_ulc_1950_1973.xlsx')

ulc = wr.hvplot.line('Ano', ['Custo Unitário do Trabalho', 'Salário médio real', 'Produtividade do trabalho'],
                         height=400,
                         width=650,
                         rot=45,
                         padding=0.02,
                         group_label='Variáveis',
                         legend='bottom',
                         cmap='tab10',
                         yformatter='%.0f',
                         xlabel='',
                         ylabel='1952=100',
                         xticks=20,
                         yticks=12,
                         xlim=(1955, 1970),
                         title='Salário, produtividade e custo unitário do trabalho, Indústria, 1955-1970'
                        ).opts(fontsize={'title': 10.2})

# %%
ulc
# Out:
# :NdOverlay   [Variáveis]
#    :Curve   [Ano]   (value)

# %% [markdown]
# ## Distribuição da renda da indústria
#
# A relação entre salário-produto real e produtividade do trabalho também possui uma dimensão *distributiva* - isto é, vinculada à repartição da renda entre lucros e salários.

# %% [markdown]
# Ao substituir a produtividade do trabalho ($\frac{O}{L})$ no custo unitário do trabalho $(\frac{w_r}{lp})$, obtemos $\frac{w_r.L}{O}$, onde $w_r.L =$ massa salarial e ${O} =$ valor adicionado na produção.

# %% [markdown]
# Em outras palavras, com essa definição é possível deduzir a participação dos salários na renda da indústria brasileira no período do PAEG (ou, inversamente, a participação dos lucros). Qual foi o resultado?

# %% [markdown]
# ## Salários e produtividade no "milagre"
#
# Agora o período do "milagre": os preços tiveram crescimento inferior a 20% ao ano em 1972-73. Os salários reais voltaram a crescer, exceto em 1970.

# %% [markdown]
# Mas *importante*: considerando a produtividade e o custo unitário do trabalho, os resultados foram desfavoráveis para os salários.

# %% [markdown]
# Ver a seguir o comportamento dos salários reais, da produtividade e do custo unitário do trabalho na indústria de transformação brasileira.

# %%
w = pd.read_excel('br_sal_paeg.xlsx')

salários = w.hvplot.line('Ano', ['Salário-Consumo IPC-MTb', 'Salário-Consumo IPC-SP', 'Salário-Produto IPA-DI'],
                         height=400,
                         width=620,
                         rot=0,
                         padding=0.02,
                         group_label='Salário real por deflator',
                         legend='bottom',
                         cmap='tab10',
                         yformatter='%.1f',
                         xlabel='',
                         ylabel='taxa de crescimento anual, %',
                         xlim=(1960, 1973),
                         xticks=12,
                         yticks=12,
                         ylim=(-15,25),
                         title='Salários médios reais da indústria manufatureira, Brasil, 1960-1973, %'
                        ).opts(fontsize={'title': 10})

# %%
salários
# Out:
# :NdOverlay   [Salário real por deflator]
#    :Curve   [Ano]   (value)

# %%
wr = pd.read_excel('br_ulc_1950_1973.xlsx')

ulc = wr.hvplot.line('Ano', ['Custo Unitário do Trabalho', 'Salário médio real', 'Produtividade do trabalho'],
                     height=400,
                     width=620,
                     rot=45,
                     padding=0.02,
                     legend='bottom',
                     group_label='Variáveis',
                     cmap='tab10',
                     yformatter='%.0f',
                     xlabel='',
                     ylabel='1952=100',
                     xlim=(1960, 1973),
                     ylim=(0,300),
                     xticks=12,
                     yticks=12,
                     title='Salário, produtividade e custo unitário do trabalho, Indústria, 1960-1973'
                    ).opts(fontsize={'title': 10})

# %%
ulc
# Out:
# :NdOverlay   [Variáveis]
#    :Curve   [Ano]   (value)

# %% [markdown]
# ## Crescimento sustentado?
#
# Por fim, diante do alto crescimento alcançado durante o "milagre", uma pergunta central pode ser feita agora.

# %% [markdown]
# Levando em consideração o endividamento externo do período, esse crescimento econômico era sustentável no médio prazo?

# %% [markdown]
# Trataremos dessa questão nas próximas aulas.

# %% [markdown]
# ## Questões
#
# Analise o balanço de pagamentos brasileiro no período estudado e responda: quais foram as principais contas que
# se alteraram de forma substancial durante o “milagre” em relação aos anos 1960?
#
# Como foi possível manter o crescimento em ritmo acelerado no “milagre” com saldos comerciais decrescentes e até negativos?
#
# O que significa, na visão de Davidoff Cruz, dizer que o endividamento externo durante o “milagre” teve causas
# “financeiras”?
#
# Descreva as principais tendências dos salários, da produtividade e do custo unitário do trabalho durante o PAEG e o "milagre". Quais foram os efeitos sobre a distribuição da renda na indústria?
