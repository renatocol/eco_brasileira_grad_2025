# %% [markdown]
#  ## <center>Economia Brasileira - FEA-USP</center>
#
# ## <center>Aula 2 - Ditadura, estabilização e reformas, 1964-1967 (parte 2)</center>
#
# ### <center>Renato Perim Colistete</center>
#
#
# #### <center>2025</center>

# %% [markdown]
# ## Objetivos
#
# Voltamos hoje à política econômica durante o governo Castelo Branco (15/4/1964 a 15/3/1967), agora vista pelo
# ângulo de seus resultados.
#
# Os gráficos e tabelas a seguir sintetizam o desempenho econômico do período. Vamos resumir e interpretar os dados diretamente das fontes.
#
# No final, veremos o contexto do crescimento de longo prazo em que se insere esse período, considerando produto e demografia.

# %% [markdown]
# ## Moeda e crédito
#
# Dois momentos críticos da oferta monetária: em 1963 (Plano Trienal) e 1965-1966 (PAEG). A oferta de crédito dos bancos privados teve comportamento semelhante, conf. a figura abaixo.

# %% [markdown]
# O PAEG foi ambíguo com relação ao controle da moeda e do crédito, oscilando entre expansão e contração.

# %% [markdown]
# A retração do crédito durante o Plano Trienal foi ainda mais forte do que a ocorrida no PAEG.

# %%
import pandas as pd
import numpy as np

import holoviews as hv
from holoviews import dim, opts
import hvplot.pandas
hv.extension('bokeh', 'matplotlib')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='e2ba6f19-0887-41e4-a4b8-e30d1e2acc16'>
#   <div id="e8cc8f4f-5ec2-4833-9716-3f7c301f22ce" data-root-id="e2ba6f19-0887-41e4-a4b8-e30d1e2acc16" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"9a04002d-adbf-433d-bca4-66a7c8d1e800":{"version":"3.4.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"e2ba6f19-0887-41e4-a4b8-e30d1e2acc16"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"5c5b9e09-681f-440f-b4cd-2ab4baabbf6c","attributes":{"plot_id":"e2ba6f19-0887-41e4-a4b8-e30d1e2acc16","comm_id":"fb7a7e189df54b7bbf2a1430ec01472e","client_comm_id":"4d99f41decac46a3ac78e132876e3b2e"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"9a04002d-adbf-433d-bca4-66a7c8d1e800","roots":{"e2ba6f19-0887-41e4-a4b8-e30d1e2acc16":"e8cc8f4f-5ec2-4833-9716-3f7c301f22ce"},"root_ids":["e2ba6f19-0887-41e4-a4b8-e30d1e2acc16"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
m = pd.read_excel('br_cred_paeg.xlsx')


moeda = m.hvplot.line('Ano', ['M', 'empréstimos'],
                      height=350,
                      width=650,
                      rot=45,
                      padding=0.02,
                      group_label='Agregados',
                      xlabel='',
                      ylabel='variação trimestral, %',
                      ylim=(-50, 50),
                      yticks=8,
                      yformatter='%.1f',
                      legend='top_left',
                      cmap='Set1',
                      title='Moeda (M1) e crédito privado, Brasil, 1962-1967 (taxa de crescimento, %)'
                     ).opts(fontsize={'title': 10.5})

# %%
moeda
# Out:
# :NdOverlay   [Agregados]
#    :Curve   [Ano]   (value)

# %% [markdown]
# ## Contas públicas
#
# Outra questão importante é o que ocorreu com as contas públicas. A participação da despesa (primária) do governo federal no PIB oscilou desde 1950, conf. a figura abaixo.

# %% [markdown]
# A queda relativa das receitas públicas na primeira metade da década de 1960 não foi acompanhada pelas despesas, resultado revertido após 1964.

# %% [markdown]
# Como consequência, o saldo das receitas e despesas primárias da União tornou-se positivo e crescente após 1964 (pergunta: o comportamento de receita e despesa foi consistente com o previsto pelo PAEG?).

# %%
contas = pd.read_excel('br_contas_paeg.xlsx')


contas_públicas = contas.hvplot.line('Ano', ['Receita', 'Despesa', 'Resultado'],
                                     height=400,
                                     width=650,
                                     rot=45,
                                     group_label='Contas públicas',
                                     padding=0.02,
                                     yformatter='%.1f',
                                     xlabel='',
                                     ylabel='%',
                                     ylim=(-5, 20),
                                     xticks=20,
                                     yticks=10,
                                     legend='bottom',
                                     cmap='tab20',
                                     title='Contas da União, Brasil, 1950-1970, em % do PIB'
                                    ).opts(fontsize={'title': 11})

# %%
contas_públicas
# Out:
# :NdOverlay   [Contas públicas]
#    :Curve   [Ano]   (value)

# %% [markdown]
# ## Federalismo
#
# Como evoluiu a distribuição das receitas públicas entre as esferas da federação no período? Ao final do governo JK, a parcela da arrecadação apropriada pelo governo federal aumentou (66% em 1958), caindo em seguida (61,6% em 1963) e atingiu um percentual novamente elevado em 1970 (66,7%).

# %% [markdown]
# Ou seja, a reforma fiscal realizada pelo PAEG centralizou mais recursos nas mãos do governo federal, em detrimento dos governos subnacionais (estados e municípios).

# %% [markdown]
# Mas como foi a distribuição da receita entre os *governos subnacionais*? Também houve centralização? A 2a figura abaixo mostra que os municípios tiveram redução na sua parcela das rendas públicas (como % do PIB) em relação aos estados.

# %%
fed = pd.read_excel('br_federalismo_paeg.xlsx')

união = fed.hvplot.bar('Ano', 'Receita União',
                       height=400,
                       width=650,
                       rot=45,
                       padding=0.02,
                       yformatter='%.1f',
                       xlabel='',
                       ylabel='%',
                       ylim=(0,80),
                       yticks=20,
                       legend='bottom',
                       color='orange',
                       title='Participação do governo central nas receitas, Brasil, 1950-1970, %')

# %%
união
# Out:
# :Bars   [Ano]   (Receita União)

# %%
fed2 = pd.read_excel('br_federalismo_paeg.xlsx')

federação = fed2.hvplot.line('Ano', ['Receita federal', 'Receita estadual', 'Receita municipal'],
                             height=400,
                             width=650,
                             rot=45,
                             group_label='Receita',
                             padding=0.02,
                             yformatter='%.1f',
                             xlabel='',
                             ylabel='%',
                             xticks=20,
                             yticks=12,
                             ylim=(0,18),
                             legend='bottom',
                             cmap='Set2',
                             title='Receitas das entidades da federação, Brasil, 1950-1970, em % do PIB'
                            ).opts(fontsize={'title': 11})

# %%
federação
# Out:
# :NdOverlay   [Receita]
#    :Curve   [Ano]   (value)

# %% [markdown]
# ## Despesas
#
# Com relação às categorias da despesa do governo geral (= todas as esferas da federação), a principal mudança foi o aumento relativo das transferências para a Previdência Social.

# %% [markdown]
# Observar também outros itens importantes da despesa do governo geral: consumo, subsídios e Formação Bruta de Capital Fixo (FBKF).

# %% [markdown]
# Ver figura:

# %%
desp = pd.read_excel('br_federalismo_paeg.xlsx')

despesas = desp.hvplot.line('Ano', ['Consumo governo', 'Subsídios', 'Assist. e Previdência', 'FBKF'],
                            height=400,
                            width=650,
                            rot=45,
                            group_label='Tipos de despesa',
                            padding=0.02,
                            yformatter='%.1f',
                            xlabel='',
                            ylabel='% do PIB',
                            xticks=20,
                            yticks=12,
                            ylim=(0,15),
                            legend='bottom',
                            cmap='Set2',
                            title='Categorias das despesas do governo geral, Brasil, 1950-1970, % do PIB'
                           ).opts(fontsize={'title': 10.5})

# %%
despesas
# Out:
# :NdOverlay   [Tipos de despesa]
#    :Curve   [Ano]   (value)

# %% [markdown]
# ## Contas externas
#
# O desequilíbrio externo tornou-se agudo desde o final da década de 1950, agravando-se ainda mais nos primeiros anos dos 1960. O ano de 1963 foi o mais crítico. Os graus de liberdade da política macroeconômica no governo Goulart foram progressivamente reduzidos.

# %% [markdown]
# A crise externa foi amenizada em 1965 e 1966, mas novamente o déficit em transações correntes explodiu de 1967 em diante.

# %% [markdown]
# A partir de 1968, porém, a situação do balanço de pagamentos *mudou radicalmente* (embora de forma apenas temporária) sob as novas condições do *mercado financeiro internacional* – o Euromercado – e as novas instituições criadas desde o PAEG (quais?). Ver figura.

# %%
bp = pd.read_excel('br_bp_paeg.xlsx')

BP = bp.hvplot.bar('Ano', ['Balança comercial', 'Transações correntes', 'Capitais', 'Saldo do BP'],
                   height=400,
                   width=650,
                   rot=0,
                   padding=0.02,
                   legend='bottom',
                   cmap='Set2',
                   stacked=True,
                   xlabel='Ano',
                   ylim=(-900, 2100),
                   yticks=12,
                   grid=False,
                   title='Balanço de pagamentos, Brasil, 1955-1970 (em milhões de US$)'
                   ).opts(fontsize={'title': 11})

# %%
BP
# Out:
# :Bars   [Ano,Variable]   (value)

# %% [markdown]
# ## Inflação
#
# O crescimento dos preços desacelerou já em 1964 e nos anos seguintes a inflação caiu substancialmente: sucesso da política de estabilização do PAEG.

# %%
price = pd.read_excel('br_price_paeg.xlsx')

preços = price.hvplot.line('Ano', ['IGP-DI'],
                           height=400,
                           width=650,
                           rot=45,
                           padding=0.02,
                           yformatter='%.1f',
                           legend='bottom',
                           color='red',
                           xlabel='',
                           ylabel='%',
                           xticks=20,
                           yticks=12,
                           ylim=(0,100),
                           title='IGP-DI, Brasil, 1950-1970 (taxa de crescimento anual, %)'
                            )

# %%
preços
# Out:
# :Curve   [Ano]   (IGP-DI)

# %% [markdown]
# ## Produção
#
# A política de estabilização do PAEG atingiu diretamente a produção já em 1965 e depois, em menor grau, em 1967.

# %% [markdown]
# O PIB cresceu apenas 2,4% em 1965 (contra 3,4% em 1964), com queda acentuada do produto industrial (-4,7%). O investimento (FBKF) também declinou em 1964-1965. Lembrar: taxas reduzidas de crescimento eram vistas como uma anomalia na época.

# %% [markdown]
# Observar que a maior queda do PIB na década ocorreu em 1963, durante a implementação do Plano Trienal. Já a maior redução do produto industrial teve lugar em 1965.

# %%
import pandas as pd
import hvplot.pandas
import holoviews as hv

pr = pd.read_excel('br_pib_paeg.xlsx')

produto = pr.hvplot.line(
    x='Ano', 
    y=['PIB', 'Produto industrial'],
    height=400,
    width=650,
    rot=0,
    group_label='Produto',
    stacked=True,
    padding=0.02,
    legend='bottom',
    cmap='tab20c',
    yformatter='%.1f',
    xlabel='Ano',
    ylabel='%',
    ylim=(-10, 30),
    title='PIB e produto industrial, Brasil, 1955-1970 (taxa anual de crescimento, %)'
).opts(fontsize={'title': 10})

linha_zero = hv.HLine(0).opts(line_dash='dashed', line_width=1, color='black')

produto_final = produto * linha_zero
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='391685d5-6ff6-4695-9937-d67f8e29a984'>
#   <div id="c7eff4eb-0ef2-4819-ab42-533f4682cb35" data-root-id="391685d5-6ff6-4695-9937-d67f8e29a984" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"eb861298-b07d-489b-abad-2c0a448235f3":{"version":"3.4.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"391685d5-6ff6-4695-9937-d67f8e29a984"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"8b1e79e1-cb29-4b8f-9ec6-b558fe8dce55","attributes":{"plot_id":"391685d5-6ff6-4695-9937-d67f8e29a984","comm_id":"85c870be07b3476c8463ee00587e5b89","client_comm_id":"311b11d2b86c4e44a2b44d7919b96a31"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"eb861298-b07d-489b-abad-2c0a448235f3","roots":{"391685d5-6ff6-4695-9937-d67f8e29a984":"c7eff4eb-0ef2-4819-ab42-533f4682cb35"},"root_ids":["391685d5-6ff6-4695-9937-d67f8e29a984"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
produto_final
# Out:
# :Overlay
#    .NdOverlay.I :NdOverlay   [Produto]
#       :Curve   [Ano]   (value)
#    .HLine.I     :HLine   [x,y]

# %% [markdown]
# ## Salários
#
# Por fim, como vimos anteriormente, o PAEG interveio diretamente no mercado de trabalho via fixação de salários e repressão sindical, constituindo um regime de compressão salarial.

# %% [markdown]
# Os salários médios do pessoal ocupado na indústria de transformação tiveram crescimento negativo em 1965, 1966 e 1967.

# %% [markdown]
# Notem também o grande aumento dos salários reais em 1963 (apesar da inflação crescente). Exemplo do conflito distributivo naquela conjuntura?

# %% [markdown]
# Conceitos: observar na figura a seguir o uso de diferentes deflatores. Lembrar das definições de salário-consumo e salário-produto. O que são?

# %%
w = pd.read_excel('br_sal_paeg.xlsx')

salários = w.hvplot.line('Ano', ['Salário-Consumo IPC-MTb', 'Salário-Consumo IPC-SP', 'Salário-Produto IPA-DI'],
                         height=400,
                         width=650,
                         rot=45,
                         padding=0.02,
                         group_label='Salário real por deflator',
                         legend='bottom',
                         cmap='tab10',
                         yformatter='%.1f',
                         xlabel='',
                         ylabel='taxa de crescimento anual, %',
                         xticks=20,
                         yticks=12,
                         ylim=(-15,25),
                         title='Crescimento dos salários da indústria manufatureira, Brasil, 1955-1970 (%)'
                        ).opts(fontsize={'title': 9.5})

# %%
salários
# Out:
# :NdOverlay   [Salário real por deflator]
#    :Curve   [Ano]   (value)

# %% [markdown]
# ## Salário e produtividade
#
# Por fim, é importante avaliar o comportamento do salário na indústria brasileira *em relação* à produtividade do trabalho. Conceito: **custo unitário do trabalho** (*unit labor cost* ou **ulc**). Ver definições e figura a seguir:

# %% [markdown]
# custo unitário do trabalho $= ulc = \frac{w_r}{lp}$

# %% [markdown]
# Onde:
#
# salário-produto $= w_r = \frac{w_n}{P}$
#
# produtividade do trabalho $= lp = \frac{O}{L}$

# %%
wr = pd.read_excel('br_ulc_1950_1973.xlsx')

ulc = wr.hvplot.line('Ano', ['Custo Unitário do Trabalho', 'Salário médio real', 'Produtividade do trabalho'],
                         height=400,
                         width=650,
                         rot=45,
                         padding=0.02,
                         group_label='Variáveis',
                         legend='bottom',
                         cmap='tab10',
                         yformatter='%.0f',
                         xlabel='',
                         ylabel='1952=100',
                         xticks=20,
                         yticks=12,
                         #ylim=(-15,25),
                         title='Salário, produtividade e custo unitário do trabalho, Indústria, 1955-1970'
                        ).opts(fontsize={'title': 10.2})

# %%
ulc
# Out:
# :NdOverlay   [Variáveis]
#    :Curve   [Ano]   (value)

# %% [markdown]
# ## Crescimento
#
# Por fim, vejamos o período no contexto do crescimento da economia brasileira desde o início do século XX.

# %% [markdown]
# A taxa média de crescimento do PIB entre 1901 e 1970 atingiu 5,1% a.a. O PIB *per capita*, por sua vez, foi de 2,7% a.a. no período (Ver, porém, possível revisão recente, aproximadamente 3,0% a.a.).

# %% [markdown]
# Ver a figura a seguir. Observem o efeito não-linear do crescimento populacional.

# %%
pibreal = pd.read_excel('br_pib_1901_75.xlsx')

PIB = pibreal.hvplot.line('Ano', ['PIB', 'PIB per capita'],
                          height=400,
                          width=550,
                          rot=45,
                          padding=0.09,
                          group_label='Produto',
                          legend='bottom',
                          xlabel='',
                          ylabel='Índice, 1901=100',
                          xlim=(1900, 1975),
                          xticks=25,
                          ylim=(0, 6000),
                          yticks=15,
                          grid=False,
                          title='PIB e PIB per capita, Brasil, 1901-1975 (em R$ de 1999, 1901=100)'
                         ).opts(fontsize={'title': 9, 'labels': 8, 'xticks': 8,'yticks': 8, 'legend': 8})

# %%
PIB
# Out:
# :NdOverlay   [Produto]
#    :Curve   [Ano]   (value)

# %% [markdown]
# ## População
#
# As características demográficas da população se alteraram substancialmente ao longo do período, com reflexos diretos sobre a taxa de crescimento *per capita*, como visto no gráfico anterior.

# %%
import pandas as pd
import holoviews as hv
import hvplot.pandas

d = pd.read_excel('br_pop_1881_1975.xlsx')
d['Ano'] = d['Ano'].astype(str)

df_long = d.melt(id_vars=['Ano'], 
                 value_vars=['Natalidade', 'Mortalidade'], 
                 var_name='Taxa', 
                 value_name='Valor')

pop = df_long.hvplot.bar(
    x='Ano',
    y='Valor',
    by='Taxa',
    width=650,
    height=400,
    rot=45, 
    padding=0.02,
    legend='bottom',
    color=['#1f77b4', '#ff7f0e'], 
    title='Taxas brutas de natalidade e mortalidade, Brasil, 1881-1975',
    fontsize=12,
    yticks=10,
    ylim=(0, 50),
    yformatter='%.1f',
    xlabel='',
    ylabel='%'
).opts(multi_level=False)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='e7b44a82-5269-484b-8025-525fe32b8fae'>
#   <div id="b959d25b-ae68-487d-9c6b-8dc2c3c6ae50" data-root-id="e7b44a82-5269-484b-8025-525fe32b8fae" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"24d282a5-d310-4795-bef3-192677b42779":{"version":"3.4.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"e7b44a82-5269-484b-8025-525fe32b8fae"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"e581f8dc-dc36-43cc-a7ea-3e81eb29f2b1","attributes":{"plot_id":"e7b44a82-5269-484b-8025-525fe32b8fae","comm_id":"33586227dddf4f5890c40b5454846e90","client_comm_id":"aded84a200df4b719ef6d34e99f4f5d2"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"24d282a5-d310-4795-bef3-192677b42779","roots":{"e7b44a82-5269-484b-8025-525fe32b8fae":"b959d25b-ae68-487d-9c6b-8dc2c3c6ae50"},"root_ids":["e7b44a82-5269-484b-8025-525fe32b8fae"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
pop
# Out:
# :Bars   [Ano,Taxa]   (Valor)
